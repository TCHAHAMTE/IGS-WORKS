# %%
#Importez la librairie Pandas
import pandas as pd

# %%
#Chargez le fichier "Produits.xlsx" de données dans un objet appelé "data"
data=pd.read_excel('Produits.xlsx')

# %%
#Copiez data dans un autre object appelé df
df=data.copy()

# %%
#Affichez les informations concernant l'objet df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nom        77 non-null     object
#  1   Categorie  77 non-null     object
#  2   Origine    77 non-null     object
#  3   Ville      77 non-null     object
#  4   Prix       77 non-null     float64
#  5   Stock      77 non-null     int64
#  6   Valeur     77 non-null     float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 4.3+ KB

# %%
#En vous basant sur les résultats de la question précédente, Combien y a-t-il d’observations et de variables dans le fichier  
#le fichier contien 77 ignes ,7 colonnes dont les variables sont de types qualitatives,reel et entier

# %%
#Affichez les 10 premières lignes des données de l'objet df
df.head(10)
# Out:
#                            Nom                  Categorie    Origine  Ville  \
# 0                 Alice Mutton                    Viandes        CEE   Lyon
# 1                Aniseed Syrup                 Condiments  Exterieur  Paris
# 2             Boston Crab Meat  Poissons et fruits de mer  Exterieur  Paris
# 3            Camembert Pierrot          Produits laitiers  Exterieur  Paris
# 4             Carnarvon Tigers  Poissons et fruits de mer  Exterieur   Lyon
# 5                         Chai                   Boissons        CEE   Lyon
# 6                        Chang                   Boissons  Exterieur   Lyon
# 7             Chartreuse verte                   Boissons  Exterieur   Lyon
# 8  Chef Antons Cajun Seasoning                 Condiments        CEE   Lyon
# 9        Chef Antons Gumbo Mix                 Condiments        CEE  Paris
#
#      Prix  Stock  Valeur
# 0  195.00      0     0.0
# 1   50.00     25  1250.0
# 2   92.00     30  2760.0
# 3  170.00      0     0.0
# 4  312.50      0     0.0
# 5   90.00     10   900.0
# 6   95.00     25  2375.0
# 7   90.00      5   450.0
# 8  110.00      0     0.0
# 9  106.75      0     0.0

# %%
#Supprimer la colonne "Valeur"
df=df.drop(['Valeur'],axis=1)
df
# Out:
#                                Nom                  Categorie    Origine  \
# 0                     Alice Mutton                    Viandes        CEE
# 1                    Aniseed Syrup                 Condiments  Exterieur
# 2                 Boston Crab Meat  Poissons et fruits de mer  Exterieur
# 3                Camembert Pierrot          Produits laitiers  Exterieur
# 4                 Carnarvon Tigers  Poissons et fruits de mer  Exterieur
# ..                             ...                        ...        ...
# 72  Uncle Bobs Organic Dried Pears              Produits secs  Exterieur
# 73                Valkoinen suklaa                   Desserts        CEE
# 74                    Vegie-spread                 Condiments  Exterieur
# 75       Wimmers gute Semmelknodel          Pates et cereales        CEE
# 76                   Zaanse koeken                   Desserts  Exterieur
#
#     Ville    Prix  Stock
# 0    Lyon  195.00      0
# 1   Paris   50.00     25
# 2   Paris   92.00     30
# 3   Paris  170.00      0
# 4    Lyon  312.50      0
# ..    ...     ...    ...
# 72  Paris  150.00     10
# 73  Paris   81.25     30
# 74  Paris  219.50      5
# 75   Lyon  166.25     30
# 76   Lyon   47.50      0
#
# [77 rows x 6 columns]

# %%
#Afficher les statistiques descriptives pour les variables quantitatives de l'objet df
df.select_dtypes(include=['float','int']).describe()
# Out:
#               Prix      Stock
# count    77.000000  77.000000
# mean    144.331818  12.467532
# std     169.075557  10.931105
# min      12.500000   0.000000
# 25%      66.250000   0.000000
# 50%      97.500000  10.000000
# 75%     166.250000  25.000000
# max    1317.500000  30.000000

# %%
#Afficher les statistiques descriptives pour les variables qualitatives de l'objet df
df.select_dtypes('object').describe()
# Out:
#                  Nom Categorie Origine Ville
# count             77        77      77    77
# unique            77         8       2     2
# top     Alice Mutton  Desserts     CEE  Lyon
# freq               1        13      40    40

# %%
#On veut afficher les produits dont la catégorie = boissons
df[df['Categorie']=='Boissons']
# Out:
#                           Nom Categorie    Origine  Ville     Prix  Stock
# 5                        Chai  Boissons        CEE   Lyon    90.00     10
# 6                       Chang  Boissons  Exterieur   Lyon    95.00     25
# 7            Chartreuse verte  Boissons  Exterieur   Lyon    90.00      5
# 11              Côte de Blaye  Boissons        CEE  Paris  1317.50     15
# 21         Guarana Fantastica  Boissons  Exterieur   Lyon    22.50      0
# 28                Ipoh Coffee  Boissons  Exterieur  Paris   230.00     25
# 31               Lakkalikoori  Boissons        CEE   Lyon    90.00     20
# 32  Laughing Lumberjack Lager  Boissons        CEE   Lyon    70.00     10
# 45              Outback Lager  Boissons  Exterieur   Lyon    75.00     30
# 53       Rhonbrau Klosterbier  Boissons        CEE  Paris    38.75     25
# 57              Sasquatch Ale  Boissons        CEE   Lyon    70.00     15
# 65             Steeleye Stout  Boissons  Exterieur   Lyon    90.00     15

# %%
#On veut afficher les produits dont la Catégorie = boissons et le prix >100
df[(df['Categorie']=='Boissons') & (df['Prix']>100)]
# Out:
#               Nom Categorie    Origine  Ville    Prix  Stock
# 11  Côte de Blaye  Boissons        CEE  Paris  1317.5     15
# 28    Ipoh Coffee  Boissons  Exterieur  Paris   230.0     25

# %%
#On veut afficher les produits dont la Catégorie = boissons et l'origine=CEE et prix > 100
df[(df['Categorie']=='Boissons') & (df['Origine']=='CEE') & (df['Prix']>100)]
# Out:
#               Nom Categorie Origine  Ville    Prix  Stock
# 11  Côte de Blaye  Boissons     CEE  Paris  1317.5     15

# %%
#On veut afficher les produits dont la (Catégorie = boissons et origine = CEE) OU (catégorie = condiment)
df[((df['Categorie']=='Boissons') & (df['Origine']=='CEE')) | (df['Categorie']=='Condiments')]
# Out:
#                                  Nom   Categorie    Origine  Ville     Prix  \
# 1                      Aniseed Syrup  Condiments  Exterieur  Paris    50.00
# 5                               Chai    Boissons        CEE   Lyon    90.00
# 8        Chef Antons Cajun Seasoning  Condiments        CEE   Lyon   110.00
# 9              Chef Antons Gumbo Mix  Condiments        CEE  Paris   106.75
# 11                     Côte de Blaye    Boissons        CEE  Paris  1317.50
# 16                      Genen Shouyu  Condiments        CEE  Paris    77.50
# 19       Grandmas Boysenberry Spread  Condiments  Exterieur   Lyon   125.00
# 23                      Gula Malacca  Condiments        CEE  Paris    97.25
# 31                      Lakkalikoori    Boissons        CEE   Lyon    90.00
# 32         Laughing Lumberjack Lager    Boissons        CEE   Lyon    70.00
# 34  Louisiana Fiery Hot Pepper Sauce  Condiments        CEE  Paris   105.25
# 35         Louisiana Hot Spiced Okra  Condiments        CEE  Paris    85.00
# 42        Northwoods Cranberry Sauce  Condiments  Exterieur   Lyon   200.00
# 44   Original Frankfurter grüne Soße  Condiments  Exterieur   Lyon    65.00
# 53              Rhonbrau Klosterbier    Boissons        CEE  Paris    38.75
# 57                     Sasquatch Ale    Boissons        CEE   Lyon    70.00
# 63                     Sirop derable  Condiments  Exterieur  Paris   142.50
# 74                      Vegie-spread  Condiments  Exterieur  Paris   219.50
#
#     Stock
# 1      25
# 5      10
# 8       0
# 9       0
# 11     15
# 16      5
# 19     25
# 23     15
# 31     20
# 32     10
# 34      0
# 35     20
# 42      0
# 44     15
# 53     25
# 57     15
# 63     25
# 74      5

# %%
#On veut afficher les produits dont (Catégorie = viande ET origine = CEE) OU (catégorie = condiment ET origine = extérieur)
df[((df['Categorie']=='Viandes') &(df['Origine']=='CEE')) | ((df['Categorie']=='Condiments') & (df['Origine']=='Exterieur'))]
# Out:
#                                 Nom   Categorie    Origine  Ville    Prix  \
# 0                      Alice Mutton     Viandes        CEE   Lyon  195.00
# 1                     Aniseed Syrup  Condiments  Exterieur  Paris   50.00
# 19      Grandmas Boysenberry Spread  Condiments  Exterieur   Lyon  125.00
# 39                  Mishi Kobe Niku     Viandes        CEE   Lyon  485.00
# 42       Northwoods Cranberry Sauce  Condiments  Exterieur   Lyon  200.00
# 44  Original Frankfurter grüne Soße  Condiments  Exterieur   Lyon   65.00
# 46                     Pate chinois     Viandes        CEE   Lyon  120.00
# 48                    Perth Pasties     Viandes        CEE  Paris  164.00
# 63                    Sirop derable  Condiments  Exterieur  Paris  142.50
# 70                        Tourtiere     Viandes        CEE  Paris   37.25
# 74                     Vegie-spread  Condiments  Exterieur  Paris  219.50
#
#     Stock
# 0       0
# 1      25
# 19     25
# 39      0
# 42      0
# 44     15
# 46     20
# 48      0
# 63     25
# 70     10
# 74      5

# %%
#On veut afficher les produits dont le prix > 70 et prix <=100
df[(df['Prix']>70) & (df['Prix']<=100)]
# Out:
#                           Nom                  Categorie    Origine  Ville  \
# 2            Boston Crab Meat  Poissons et fruits de mer  Exterieur  Paris
# 5                        Chai                   Boissons        CEE   Lyon
# 6                       Chang                   Boissons  Exterieur   Lyon
# 7            Chartreuse verte                   Boissons  Exterieur   Lyon
# 16               Genen Shouyu                 Condiments        CEE  Paris
# 23               Gula Malacca                 Condiments        CEE  Paris
# 27                Inlagd Sill  Poissons et fruits de mer  Exterieur  Paris
# 31               Lakkalikoori                   Boissons        CEE   Lyon
# 35  Louisiana Hot Spiced Okra                 Condiments        CEE  Paris
# 38                   Maxilaku                   Desserts        CEE   Lyon
# 45              Outback Lager                   Boissons  Exterieur   Lyon
# 47                    Pavlova                   Desserts        CEE  Paris
# 52             Ravioli Angelo          Pates et cereales  Exterieur  Paris
# 54                 Rod Kaviar  Poissons et fruits de mer        CEE  Paris
# 65             Steeleye Stout                   Boissons  Exterieur   Lyon
# 73           Valkoinen suklaa                   Desserts        CEE  Paris
#
#       Prix  Stock
# 2    92.00     30
# 5    90.00     10
# 6    95.00     25
# 7    90.00      5
# 16   77.50      5
# 23   97.25     15
# 27   95.00     20
# 31   90.00     20
# 35   85.00     20
# 38  100.00     15
# 45   75.00     30
# 47   87.25     10
# 52   97.50     20
# 54   75.00      5
# 65   90.00     15
# 73   81.25     30

# %%
#Lister les aliments dont le prix est compris entre 100 et 200, et qui sont des « viandes »
df[((df['Prix']>100) & (df['Prix']<200)) & (df['Categorie']=='Viandes')]
# Out:
#               Nom Categorie Origine  Ville   Prix  Stock
# 0    Alice Mutton   Viandes     CEE   Lyon  195.0      0
# 46   Pate chinois   Viandes     CEE   Lyon  120.0     20
# 48  Perth Pasties   Viandes     CEE  Paris  164.0      0

# %%
#Lister les 15 produits les moins chers
df.groupby(['Prix','Categorie']).min().iloc[:15,:1]
# Out:
#                                                             Nom
# Prix  Categorie
# 12.50 Produits laitiers                                 Geitost
# 22.50 Boissons                               Guarana Fantastica
# 30.00 Poissons et fruits de mer                           Konbu
# 35.00 Pates et cereales                                Filo Mix
# 37.25 Viandes                                         Tourtiere
# 38.75 Boissons                             Rhonbrau Klosterbier
# 45.00 Pates et cereales                                Tunnbrod
# 46.00 Desserts                       Teatime Chocolate Biscuits
# 47.50 Desserts                                    Zaanse koeken
#       Poissons et fruits de mer                     Røgede sild
# 48.25 Poissons et fruits de mer  Jacks New England Clam Chowder
# 50.00 Condiments                                  Aniseed Syrup
#       Desserts                               Sir Rodneys Scones
#       Produits secs                               Longlife Tofu
# 60.00 Poissons et fruits de mer                       Spegesild

# %%
#Calculer la moyenne de prix des boissons distribuées à Lyon (pivot_table)
#df[(df['Categorie']=='Boissons') & (df['Ville']=='Lyon')]
#pivot_table=
pd.pivot_table(df ,columns='Prix',index=df[df['Ville']=='Lyon'], aggfunc='mean' )
#pivot_table
#pd.crosstab(df['Categorie'],df['Ville'])
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Alice Mutton, Viandes, CEE, Lyon, 195.0, 0), (Aniseed Syrup, Condiments, Exterieur, Paris, 50.0, 25), (Boston Crab Meat, Poissons et fruits de mer, Exterieur, Paris, 92.0, 30), (Camembert Pierrot, Produits laitiers, Exterieur, Paris, 170.0, 0), (Carnarvon Tigers, Poissons et fruits de mer, Exterieur, Lyon, 312.5, 0), (Chai, Boissons, CEE, Lyon, 90.0, 10), (Chang, Boissons, Exterieur, Lyon, 95.0, 25), (Chartreuse verte, Boissons, Exterieur, Lyon, 90.0, 5), (Chef Antons Cajun Seasoning, Condiments, CEE, Lyon, 110.0, 0), (Chef Antons Gumbo Mix, Condiments, CEE, Paris, 106.75, 0), (Chocolade, Desserts, CEE, Paris, 63.75, 25), (Côte de Blaye, Boissons, CEE, Paris, 1317.5, 15), (Escargots de Bourgogne, Poissons et fruits de mer, Exterieur, Paris, 66.25, 20), (Filo Mix, Pates et cereales, Exterieur, Paris, 35.0, 25), (Flotemysost, Produits laitiers, CEE, Lyon, 107.5, 0), (Geitost, Produits laitiers, CEE, Lyon, 12.5, 20), (Genen Shouyu, Condiments, CEE, Paris, 77.5, 5), (Gnocchi di nonna Alice, Pates et cereales, CEE, Lyon, 190.0, 30), (Gorgonzola Telino, Produits laitiers, CEE, Lyon, 62.5, 20), (Grandmas Boysenberry Spread, Condiments, Exterieur, Lyon, 125.0, 25), (Gravad lax, Poissons et fruits de mer, Exterieur, Lyon, 130.0, 25), (Guarana Fantastica, Boissons, Exterieur, Lyon, 22.5, 0), (Gudbrandsdalsost, Produits laitiers, Exterieur, Paris, 180.0, 15), (Gula Malacca, Condiments, CEE, Paris, 97.25, 15), (Gumbar Gummibarchen, Desserts, CEE, Paris, 156.15, 0), (Gustafs Knackebrod, Pates et cereales, CEE, Paris, 105.0, 25), (Ikura, Poissons et fruits de mer, Exterieur, Paris, 155.0, 0), (Inlagd Sill, Poissons et fruits de mer, Exterieur, Paris, 95.0, 20), (Ipoh Coffee, Boissons, Exterieur, Paris, 230.0, 25), (Jacks New England Clam Chowder, Poissons et fruits de mer, Exterieur, Lyon, 48.25, 10), (Konbu, Poissons et fruits de mer, CEE, Lyon, 30.0, 5), (Lakkalikoori, Boissons, CEE, Lyon, 90.0, 20), (Laughing Lumberjack Lager, Boissons, CEE, Lyon, 70.0, 10), (Longlife Tofu, Produits secs, Exterieur, Lyon, 50.0, 5), (Louisiana Fiery Hot Pepper Sauce, Condiments, CEE, Paris, 105.25, 0), (Louisiana Hot Spiced Okra, Condiments, CEE, Paris, 85.0, 20), (Manjimup Dried Apples, Produits secs, CEE, Lyon, 265.0, 10), (Mascarpone Fabioli, Produits laitiers, Exterieur, Lyon, 160.0, 25), (Maxilaku, Desserts, CEE, Lyon, 100.0, 15), (Mishi Kobe Niku, Viandes, CEE, Lyon, 485.0, 0), (Mozzarella di Giovanni, Produits laitiers, Exterieur, Lyon, 174.0, 0), (Nord-Ost Matjeshering, Poissons et fruits de mer, CEE, Lyon, 129.45, 15), (Northwoods Cranberry Sauce, Condiments, Exterieur, Lyon, 200.0, 0), (NuNuCa Nub-Nougat-Creme, Desserts, Exterieur, Lyon, 70.0, 30), (Original Frankfurter grüne Soße, Condiments, Exterieur, Lyon, 65.0, 15), (Outback Lager, Boissons, Exterieur, Lyon, 75.0, 30), (Pate chinois, Viandes, CEE, Lyon, 120.0, 20), (Pavlova, Desserts, CEE, Paris, 87.25, 10), (Perth Pasties, Viandes, CEE, Paris, 164.0, 0), (Queso Cabrales, Produits laitiers, CEE, Paris, 105.0, 30), (Queso Manchego La Pastora, Produits laitiers, CEE, Paris, 190.0, 0), (Raclette Courdavault, Produits laitiers, CEE, Paris, 275.0, 0), (Ravioli Angelo, Pates et cereales, Exterieur, Paris, 97.5, 20), (Rhonbrau Klosterbier, Boissons, CEE, Paris, 38.75, 25), (Rod Kaviar, Poissons et fruits de mer, CEE, Paris, 75.0, 5), (Rossle Sauerkraut, Produits secs, CEE, Paris, 228.0, 0), (Røgede sild, Poissons et fruits de mer, Exterieur, Paris, 47.5, 15), (Sasquatch Ale, Boissons, CEE, Lyon, 70.0, 15), (Schoggi Schokolade, Desserts, CEE, Paris, 219.5, 30), (Scottish Longbreads, Desserts, CEE, Paris, 62.5, 15), (Singaporean Hokkien Fried Mee, Pates et cereales, Exterieur, Lyon, 70.0, 0), (Sir Rodneys Marmalade, Desserts, Exterieur, Lyon, 405.0, 0), (Sir Rodneys Scones, Desserts, CEE, Lyon, 50.0, 5), (Sirop derable, Condiments, Exterieur, Paris, 142.5, 25), (Spegesild, Poissons et fruits de mer, Exterieur, Lyon, 60.0, 0), (Steeleye Stout, Boissons, Exterieur, Lyon, 90.0, 15), (Tarte au  ...
#
# [77 rows x 0 columns]

# %%
#Quels sont les 5 produits les moins chers vendus à Lyon ?
dff=df[['Categorie','Prix','Ville']].groupby(['Prix']).min()
dff[dff['Ville']=='Lyon'].head()
# Out:
#                       Categorie Ville
# Prix
# 12.5          Produits laitiers  Lyon
# 22.5                   Boissons  Lyon
# 30.0  Poissons et fruits de mer  Lyon
# 46.0                   Desserts  Lyon
# 47.5                   Desserts  Lyon

# %%
#En utilisant une boucle afficher la representation graphique de toutes les variables quantitative
#importons la bibliotheque matplotlib
import matplotlib.pyplot as plt
liste_qual=df.select_dtypes(include=['object']).columns
liste_qual
a=1
plt.figure(figsize=(30,10))
for element in liste_qual:
    plt.subplot(1,4,a)
    df[element].value_counts().plot(kind='bar')
    a+=1
    plt.title(element)
    plt.legend(element)

# %%
#En utilisant une boucle afficher la representation graphique de toutes les variables quanliative
liste_quant=df.select_dtypes(include=['int','float']).columns
b=1
for alpha in liste_quant:
    plt.subplot(1,2,b)
    df[alpha].value_counts().plot(kind='hist')
    b+=1
    plt.title(alpha)
    plt.legend(alpha)
