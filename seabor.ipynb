# %% [markdown]
# <a href="https://colab.research.google.com/github/TCHAHAMTE/IGS-WORKS/blob/main/seabor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
np.random.seed(0)
x=np.random.randn(10)
x
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ])

# %%
 print(max(x),'et',min(x))
# Out:
# 2.240893199201458 et -0.977277879876411

# %%
sns.displot(x)

# %%
sns.distplot(x)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.kdeplot(data=titanic,x= 'age')

# %%
titanic['age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
sns.kdeplot(data=iris)

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')

# %%
sns.kdeplot(data=tips, x='total_bill',hue='sex',multiple='stack')

# %%
tips[['total_bill','sex']].value_counts()
# Out:
# total_bill  sex
# 13.42       Female    2
# 13.00       Female    2
# 13.81       Male      2
# 15.69       Male      2
# 10.34       Male      2
#                      ..
# 15.81       Male      1
# 15.95       Male      1
# 15.98       Male      1
#             Female    1
# 50.81       Male      1
# Length: 235, dtype: int64

# %%
tips.agg=tips.groupby('size').agg(total_bill=('total_bill','mean'),n=('total_bill','count'))

# %%
tips.agg
# Out:
#       total_bill    n
# size
# 1       7.242500    4
# 2      16.448013  156
# 3      23.277632   38
# 4      28.613514   37
# 5      30.068000    5
# 6      34.830000    4

# %%
sns.kdeplot(data=tips.agg, x='total_bill',weights='n')

# %%
data=sns.load_dataset('/Produits.xlsx')
import os
os.chdir('/Produits.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-ae6435d69337> in <module>
# ----> 1 data=sns.load_dataset('/Produits.xlsx')
#       2 import os
#       3 os.chdir('/Produits.xlsx')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: '/Produits.xlsx' is not one of the example datasets.

# %%
data=pd.read_excel('/Produits.xlsx')

# %%
data
# Out:
#                                Nom                  Categorie    Origine  \
# 0                     Alice Mutton                    Viandes        CEE
# 1                    Aniseed Syrup                 Condiments  Exterieur
# 2                 Boston Crab Meat  Poissons et fruits de mer  Exterieur
# 3                Camembert Pierrot          Produits laitiers  Exterieur
# 4                 Carnarvon Tigers  Poissons et fruits de mer  Exterieur
# ..                             ...                        ...        ...
# 72  Uncle Bobs Organic Dried Pears              Produits secs  Exterieur
# 73                Valkoinen suklaa                   Desserts        CEE
# 74                    Vegie-spread                 Condiments  Exterieur
# 75       Wimmers gute Semmelknodel          Pates et cereales        CEE
# 76                   Zaanse koeken                   Desserts  Exterieur
#
#     Ville    Prix  Stock  Valeur
# 0    Lyon  195.00      0     0.0
# ...

# %%
data_prv=data.groupby(['Ville','Categorie']).agg(prix_moyenne=('Prix','mean'),Categorie=('Categorie','count'))

# %%
data_prv
# Out:
#                                  prix_moyenne  Categorie
# Ville Categorie
# Lyon  Boissons                      76.944444          9
#       Condiments                   125.000000          4
#       Desserts                     119.750000          6
#       Pates et cereales            142.083333          3
#       Poissons et fruits de mer    118.366667          6
#       Produits laitiers            103.300000          5
#       Produits secs                143.750000          3
#       Viandes                      354.737500          4
# Paris Boissons                     528.750000          3
#       Condiments                   110.468750          8
#       Desserts                     130.985714          7
#       Pates et cereales             70.625000          4
#       Poissons et fruits de mer     88.458333          6
#       Produits laitiers            184.000000          5
#       Produits secs                189.000000          2
# ...

# %%
sns.kdeplot(data=data,x='Prix', hue='Categorie',fill=True,alpha=.3)#bw_adjust=100
sns.set_theme(style='darkgrid')
plt.title('essayons voir ce que sava donner')
# Out:
# Text(0.5, 1.0, 'essayons voir ce que sava donner')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='smoker',marker='o', s=100)

# %%
dict(bins=25, fill=False)
# Out:
# {'bins': 25, 'fill': False}

# %%
sns.get_dataset_names()

# %%
var=titanic.isna().sum()/titanic.shape[0]

# %%
var[var<0.1].columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-160-d4305a33d39a> in <module>
# ----> 1 var[var<0.1].columns
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
df=titanic.copy()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['alone'].astype('category').value_counts()
# Out:
# True     537
# False    354
# Name: alone, dtype: int64

# %%
df['sex'].astype('category')
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: category
# Categories (2, object): ['female', 'male']

# %%
sns.pairplot(data=df[['age']], hue='sex')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
qual=[df.select_dtypes('object').columns]

# %%
for a in qual:
  sns.displot(a)

# %%
quant=[df.select_dtypes(exclude='object').columns]

# %%
df2=sns.load_dataset('penguins')

# %%
df2
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.pairplot(data=df2, hue='sex',height=2)

# %%
df2.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(data=df2,x='species',y='body_mass_g', palette='Blues_d',errcolor='red',hue='sex')

# %%
data
# Out:
#                                Nom                  Categorie    Origine  \
# 0                     Alice Mutton                    Viandes        CEE
# 1                    Aniseed Syrup                 Condiments  Exterieur
# 2                 Boston Crab Meat  Poissons et fruits de mer  Exterieur
# 3                Camembert Pierrot          Produits laitiers  Exterieur
# 4                 Carnarvon Tigers  Poissons et fruits de mer  Exterieur
# ..                             ...                        ...        ...
# 72  Uncle Bobs Organic Dried Pears              Produits secs  Exterieur
# 73                Valkoinen suklaa                   Desserts        CEE
# 74                    Vegie-spread                 Condiments  Exterieur
# 75       Wimmers gute Semmelknodel          Pates et cereales        CEE
# 76                   Zaanse koeken                   Desserts  Exterieur
#
#     Ville    Prix  Stock  Valeur
# 0    Lyon  195.00      0     0.0
# ...

# %%
sns.barplot(data=data, x='Categorie',y='Prix',hue='Origine')

# %%
np.random.rand(10,12)
# Out:
# array([[0.79172504, 0.52889492, 0.56804456, 0.92559664, 0.07103606,
#         0.0871293 , 0.0202184 , 0.83261985, 0.77815675, 0.87001215,
#         0.97861834, 0.79915856],
#        [0.46147936, 0.78052918, 0.11827443, 0.63992102, 0.14335329,
#         0.94466892, 0.52184832, 0.41466194, 0.26455561, 0.77423369,
#         0.45615033, 0.56843395],
#        [0.0187898 , 0.6176355 , 0.61209572, 0.616934  , 0.94374808,
#         0.6818203 , 0.3595079 , 0.43703195, 0.6976312 , 0.06022547,
#         0.66676672, 0.67063787],
#        [0.21038256, 0.1289263 , 0.31542835, 0.36371077, 0.57019677,
#         0.43860151, 0.98837384, 0.10204481, 0.20887676, 0.16130952,
#         0.65310833, 0.2532916 ],
#        [0.46631077, 0.24442559, 0.15896958, 0.11037514, 0.65632959,
#         0.13818295, 0.19658236, 0.36872517, 0.82099323, 0.09710128,
#         0.83794491, 0.09609841],
#        [0.97645947, 0.4686512 , 0.97676109, 0.60484552, 0.73926358,
# ...

# %%
sns.heatmap(df.isna())

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
flights=sns.load_dataset('flights')

# %%
flight=flights.pivot('year','month','passengers')

# %%
flight
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
b=sns.heatmap(flight,annot=True ,fmt='d')

# %%
pivot_t=data[['Categorie','Ville','Prix']]

# %%
pivot_t
# Out:
#                     Categorie  Ville    Prix
# 0                     Viandes   Lyon  195.00
# 1                  Condiments  Paris   50.00
# 2   Poissons et fruits de mer  Paris   92.00
# 3           Produits laitiers  Paris  170.00
# 4   Poissons et fruits de mer   Lyon  312.50
# ..                        ...    ...     ...
# 72              Produits secs  Paris  150.00
# 73                   Desserts  Paris   81.25
# 74                 Condiments  Paris  219.50
# 75          Pates et cereales   Lyon  166.25
# 76                   Desserts   Lyon   47.50
#
# [77 rows x 3 columns]

# %%
data_p=pivot_t.pivot('Categorie','Ville','Prix')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-276-f5e1101855f2> in <module>
# ----> 1 data_p=pivot_t.pivot('Categorie','Ville','Prix')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in unstack(self, level, fill_value)
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=77, step=1)
